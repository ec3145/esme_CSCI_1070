# %%
import numpy as np 
import pandas as pd
from sklearn import tree
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

diabetes_df = pd.read_csv("diabetes.csv")
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.model_selection import train_test_split

X = diabetes_df.drop('Outcome', axis=1)
y = diabetes_df['Outcome']
X_train,X_test, y_train,y_test = train_test_split(X,y,
                                                  test_size=0.3,
                                                  random_state=42)

# %%
#descision tree classfier
#deep and comples trees 

model = tree.DecisionTreeClassifier(max_depth=25, random_state=42,min_samples_split=2, min_samples_leaf=1)

# %%
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.71      0.76       151
#            1       0.56      0.69      0.61        80
#
#     accuracy                           0.70       231
#    macro avg       0.68      0.70      0.69       231
# weighted avg       0.72      0.70      0.71       231

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
#recall
#tp/tp+fn
55/(55+25)
# Out:
# 0.6875

# %%
import matplotlib.pyplot as plt
tree.plot_tree(model, feature_names = list(X.columns),
               filled =True, fontsize=6, rounded=True, max_depth=3 )

plt.show()
plt.savefig("tree.svg")

# %%
names = [ {'name': 'ricky'}, {'name': 'joseph'},{'name': 'jacob'} , {'name': 'fabian'} ]
def format_names(names):
    name_list = [name['name'] for name in names]
    if name_list:
        if name_list[1:]:
            return ', '.join(name_list[:-1]) + ' & ' +name_list[-1]
        else:
            return name_list[0]
    else:
        return ''
game_names = format_names(names)
print(game_names)
# Out:
# ricky, joseph, jacob & fabian
