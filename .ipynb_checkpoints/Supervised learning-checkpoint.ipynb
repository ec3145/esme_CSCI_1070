# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

crime_df = pd.read_csv ("crime_data.csv")
crime_df
# Out:
#       X1    X2  X3  X4  X5  X6  X7
# 0    478   184  40  74  11  31  20
# 1    494   213  32  72  11  43  18
# 2    643   347  57  70  18  16  16
# 3    341   565  31  71  11  25  19
# 4    773   327  67  72   9  29  24
# 5    603   260  25  68   8  32  15
# 6    484   325  34  68  12  24  14
# 7    546   102  33  62  13  28  11
# 8    424    38  36  69   7  25  12
# 9    548   226  31  66   9  58  15
# 10   506   137  35  60  13  21   9
# 11   819   369  30  81   4  77  36
# 12   541   109  44  66   9  37  12
# 13   491   809  32  67  11  37  16
# 14   514    29  30  65  12  35  11
# 15   371   245  16  64  10  42  14
# 16   457   118  29  64  12  21  10
# 17   437   148  36  62   7  81  27
# 18   570   387  30  59  15  31  16
# 19   432    98  23  56  15  50  15
# 20   619   608  33  46  22  24   8
# 21   357   218  35  54  14  27  13
# 22   623   254  38  54  20  22  11
# 23   547   697  44  45  26  18   8
# 24   792   827  28  57  12  23  11
# 25   799   693  35  57   9  60  18
# 26   439   448  31  61  19  14  12
# 27   867   942  39  52  17  31  10
# 28   912  1017  27  44  21  24   9
# 29   462   216  36  43  18  23   8
# 30   859   673  38  48  19  22  10
# 31   805   989  46  57  14  25  12
# 32   652   630  29  47  19  25   9
# 33   776   404  32  50  19  21   9
# 34   919   692  39  48  16  32  11
# 35   732  1517  44  49  13  31  14
# 36   657   879  33  72  13  13  22
# 37  1419   631  43  59  14  21  13
# 38   989  1375  22  49   9  46  13
# 39   821  1139  30  54  13  27  12
# 40  1740  3545  86  62  22  18  15
# 41   815   706  30  47  17  39  11
# 42   760   451  32  45  34  15  10
# 43   936   433  43  48  26  23  12
# 44   863   601  20  69  23   7  12
# 45   783  1024  55  42  23  23  11
# 46   715   457  44  49  18  30  12
# 47  1504  1441  37  57  15  35  13
# 48  1324  1022  82  72  22  15  16
# 49   940  1244  66  67  26  18  16

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\python\python39\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\python\python39\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\python\python39\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python39\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\python39\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.1)
# Requirement already satisfied: six>=1.5 in c:\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.heatmap(crime_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
crime_df.columns
#may have extra spaces or junk so we need to do this to see the columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7'], dtype='object')

# %%
from sklearn.linear_model import LinearRegression

crime_df = crime_df[['X5','X1']]
# X is what were using to predict Y is what were predicting 
X = np.array(crime_df['X5']).reshape(-1,1)

y= np.array(crime_df['X1']).reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
regression_model = LinearRegression()
regression_model
# Out:
# LinearRegression()

# %%
y_pred = regression_model.predict(X_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 y_pred = regression_model.predict(X_test)
#       2 y_pred
#
# File C:\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File C:\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#
# File C:\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
accuracy_score = regression_model.score(X_test, y_test)
print(accuracy_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 accuracy_score = regression_model.score(X_test, y_test)
#       2 print(accuracy_score)
#
# NameError: name 'regression_model' is not defined

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
plt.scatter(X_test, y_test, color = 'm')
plt.plot(X_test, y_test)

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighbors
from
